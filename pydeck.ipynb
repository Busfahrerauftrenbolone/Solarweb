# %%
# !pip install pydeck
# !pip install OWSlib
# Out:
# Requirement already satisfied: pydeck in c:\users\manav\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\manav\anaconda3\lib\site-packages (from pydeck) (1.21.5)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\manav\anaconda3\lib\site-packages (from pydeck) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\manav\anaconda3\lib\site-packages (from jinja2>=2.10.1->pydeck) (2.0.1)
# Requirement already satisfied: OWSlib in c:\users\manav\anaconda3\lib\site-packages (0.29.3)
# Requirement already satisfied: python-dateutil>=1.5 in c:\users\manav\anaconda3\lib\site-packages (from OWSlib) (2.8.2)
# Requirement already satisfied: pytz in c:\users\manav\anaconda3\lib\site-packages (from OWSlib) (2021.3)
# Requirement already satisfied: lxml in c:\users\manav\anaconda3\lib\site-packages (from OWSlib) (4.8.0)
# Requirement already satisfied: requests>=1.0 in c:\users\manav\anaconda3\lib\site-packages (from OWSlib) (2.27.1)
# Requirement already satisfied: pyyaml in c:\users\manav\anaconda3\lib\site-packages (from OWSlib) (6.0)
# Requirement already satisfied: six>=1.5 in c:\users\manav\anaconda3\lib\site-packages (from python-dateutil>=1.5->OWSlib) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\manav\anaconda3\lib\site-packages (from requests>=1.0->OWSlib) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manav\anaconda3\lib\site-packages (from requests>=1.0->OWSlib) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manav\anaconda3\lib\site-packages (from requests>=1.0->OWSlib) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manav\anaconda3\lib\site-packages (from requests>=1.0->OWSlib) (1.26.9)

# %%
from owslib.wfs import WebFeatureService

# Define the URL of the WFS service 
#https://data.wien.gv.at/daten/geo?version=1.0.0&typeName=ogdwien:FMZKBKMOGD&outputFormat=shape-zip&SRS=EPSG:31256&BBOX=2748,341794,4516,
wfs_url = 'https://data.wien.gv.at/daten/geo?'

# Connect to the WFS service
wfs = WebFeatureService(wfs_url, version='1.1.0')

# Get the available layers
print("Available layers:")
for typename, title in wfs.contents.items():
    print(f"- {typename}: {title}")


# Note: Adjust the parameters (URL, layer_name, bounding box, etc.) based on your specific WFS service and requirements.
# Out:
# pyproj not installed
# Available layers:
# - ogdwien:PLANUNGASTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FF40>
# - ogdwien:SCOOTERABSTELLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FEE0>
# - ogdwien:ABWASSERWAERMEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FFD0>
# - ogdwien:ABWARMEPOTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FF70>
# - ogdwien:ADRESSENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FF10>
# - ogdwien:ALLESGURGELTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FEB0>
# - ogdwien:ALTSTOFFSAMMLUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FE50>
# - ogdwien:AMBULANZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FDF0>
# - ogdwien:ENERGIEAMPELEWSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FD90>
# - ogdwien:ENERGIEAMPELGWPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FD30>
# - ogdwien:AKUSTISCHEAMPELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02FCD0>
# - ogdwien:AMPELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB02F970>
# - ogdwien:ANLAGENLEISTUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACAFECEE0>
# - ogdwien:PARKENANRAINEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEB20>
# - ogdwien:ARCHAEOSDLGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEAC0>
# - ogdwien:APOTHEKEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEA60>
# - ogdwien:FUNDPUNKTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEA00>
# - ogdwien:ARCHAEOSTRASSENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE9A0>
# - ogdwien:ARZTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE940>
# - ogdwien:AUSBLICKSPUNKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE8E0>
# - ogdwien:BADESTELLENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE880>
# - ogdwien:BANKAUSTRIAOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE820>
# - ogdwien:FMZKBKMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE7C0>
# - ogdwien:BAUMKATOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE760>
# - ogdwien:GEBAEUDETYPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE700>
# - ogdwien:BEFUNDARCHAEOOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE6A0>
# - ogdwien:BEGEGNUNGSZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE640>
# - ogdwien:BEHINDERTENPARKPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE5E0>
# - ogdwien:BERATUNGSZENTROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE580>
# - ogdwien:BLICKBETRACHTABOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE520>
# - ogdwien:BLICKBETRACHTCOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE4C0>
# - ogdwien:BEZIRKSGRENZEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE460>
# - ogdwien:BIOSPHPARKFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE400>
# - ogdwien:BTKARTIERUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE3A0>
# - ogdwien:BTKLBACHOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE340>
# - ogdwien:SICHTBARKEITPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE2E0>
# - ogdwien:M29BOHROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE280>
# - ogdwien:BOTSCHAFTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE220>
# - ogdwien:BRUECKENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE1C0>
# - ogdwien:BRUECKETUNNELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE160>
# - ogdwien:BUSHALTEZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE100>
# - ogdwien:BUSPARKPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE0A0>
# - ogdwien:BUSVERBOTSZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE040>
# - ogdwien:BUECHEREIOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BE0D0>
# - ogdwien:BUERGERDIENSTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEE20>
# - ogdwien:COVIDGURGELTESTABHOLUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEEB0>
# - ogdwien:COVIDGURGELTESTSONNTAGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEF10>
# - ogdwien:COVIDGURGELTESTWOCHENTAGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEF70>
# - ogdwien:COVIDIMPFUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BEF40>
# - ogdwien:COVIDTESTSTRASSEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BED60>
# - ogdwien:CAMPINGPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BED30>
# - ogdwien:CARSHARINGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BECD0>
# - ogdwien:CHRISTBAUMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE3A0>
# - ogdwien:CITYBIKEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE1C0>
# - ogdwien:COOLESTRASSENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE220>
# - ogdwien:DACHKATASTEROBJEKTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE2E0>
# - ogdwien:DAUERZAEHLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE430>
# - ogdwien:DEFIBRILLATOROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE7C0>
# - ogdwien:DONAUINSFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE880>
# - ogdwien:DONAUINSPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE820>
# - ogdwien:DONAUINSLTSYOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE130>
# - ogdwien:DONAUKILOMETEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE730>
# - ogdwien:ESCOOTPARKVERBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE400>
# - ogdwien:EUPROJEKTNEUOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE4F0>
# - ogdwien:EUPROJEKTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE940>
# - ogdwien:EINBAHNOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE040>
# - ogdwien:ELADESTELLEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE0A0>
# - ogdwien:ERDWAERMEPOTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE100>
# - ogdwien:ERGEBNIS_BV201_V_F: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE250>
# - ogdwien:WAHLERGEBNISBP221OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE2B0>
# - ogdwien:ERGEBNIS_GR201_V_F: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE9A0>
# - ogdwien:WAHLSPREU2019OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE4C0>
# - ogdwien:FMZKGEBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CE790>
# - ogdwien:FMZKGEWOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEA60>
# - ogdwien:FMZKGRUEN1OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEAC0>
# - ogdwien:FMZKGRUEN2OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEB20>
# - ogdwien:FMZKMAUOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEB80>
# - ogdwien:FMZKVERKEHR1OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEBE0>
# - ogdwien:FMZKVERKEHR2OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEC40>
# - ogdwien:FAHRRADABSTELLANLAGEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CECA0>
# - ogdwien:FAHRSCHULEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CED00>
# - ogdwien:FAMHEBAMMEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CED60>
# - ogdwien:FIAKEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEDC0>
# - ogdwien:FLIESSGEWOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEE20>
# - ogdwien:FORTIFIKATIONOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEE80>
# - ogdwien:FRANZKATOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEEE0>
# - ogdwien:FREQUENZKARTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEF40>
# - ogdwien:FRIEDHOFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0CEFA0>
# - ogdwien:FUNDBOXENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD040>
# - ogdwien:FUSSGEHERZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD0A0>
# - ogdwien:ENERGIEGWPABGROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD100>
# - ogdwien:GABELPUNKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD160>
# - ogdwien:GARAGENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD1C0>
# - ogdwien:GEBIETSBETREUUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD220>
# - ogdwien:GEBAEUDEINFOOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD280>
# - ogdwien:ENGEFPVANLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD2E0>
# - ogdwien:ENGEFSTANLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD340>
# - ogdwien:SISGEHSTEIGABSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD3A0>
# - ogdwien:GSTGBREITEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD400>
# - ogdwien:GEMBAUTENFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD460>
# - ogdwien:GENFLWIDMUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD4C0>
# - ogdwien:GEONAMENSVERZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD520>
# - ogdwien:GENFLWOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD580>
# - ogdwien:GEONAMENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD5E0>
# - ogdwien:KULTURWIKIOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD640>
# - ogdwien:GESCHBIOFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD6A0>
# - ogdwien:GESCHLANDTEILEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD700>
# - ogdwien:DONAUKILOMETER2OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD760>
# - ogdwien:GRILLPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD7C0>
# - ogdwien:GRILLZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD820>
# - ogdwien:GRDSTKSTADTBEFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD880>
# - ogdwien:RADGRAETZELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD8E0>
# - ogdwien:GRUENGEWOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD940>
# - ogdwien:GRUENFREIFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BD9A0>
# - ogdwien:HALTESTELLEWLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDA00>
# - ogdwien:HAUPTSTRARCHOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDA60>
# - ogdwien:HAUSBETREUUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDAC0>
# - ogdwien:HISTGARTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDB20>
# - ogdwien:SYNAGOGENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDB80>
# - ogdwien:HISTWASSERLTGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDBE0>
# - ogdwien:PLANUNGAUTOBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDC40>
# - ogdwien:PLANUNGHPTSTROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDCA0>
# - ogdwien:PLANUNGKNOTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDD00>
# - ogdwien:PLANUNGSCHNELLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDD60>
# - ogdwien:HWGEFAHROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDDC0>
# - ogdwien:HWASSERFLUTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDE20>
# - ogdwien:UNTERKUNFTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDE80>
# - ogdwien:HUNDESACKERLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDEE0>
# - ogdwien:HUNDEZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDF40>
# - ogdwien:HYDRANTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0BDFA0>
# - ogdwien:HOEHENFESTPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC040>
# - ogdwien:HOEHENFESTPKTADRIAOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC0A0>
# - ogdwien:HOEHENLINIEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC100>
# - ogdwien:IMPFSTELLEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC160>
# - ogdwien:ENINNOVPRJOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC1C0>
# - ogdwien:ENINNOVPRJV2OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC220>
# - ogdwien:ENINNOVPRJFOTOOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC280>
# - ogdwien:INTORGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC2E0>
# - ogdwien:KAPPAZUNDERIMAGEPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC340>
# - ogdwien:KAPPAZUNDERLIDARFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC3A0>
# - ogdwien:KAPPAZUNDERPANOPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC400>
# - ogdwien:KASERNEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC460>
# - ogdwien:JGDANGEBOTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC4C0>
# - ogdwien:KINDERGARTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC520>
# - ogdwien:ENERGIERAUMPLANOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC580>
# - ogdwien:KRANKENHAUSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC5E0>
# - ogdwien:KULTURSOMMEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC640>
# - ogdwien:KUNSTWERKOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC6A0>
# - ogdwien:KURZPARKZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC700>
# - ogdwien:KURZPARKSTREIFENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC760>
# - ogdwien:PARKENBERECHTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC7C0>
# - ogdwien:PARKENGELTUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC820>
# - ogdwien:LADEZONENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC880>
# - ogdwien:LADEZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC8E0>
# - ogdwien:LAGERBAUOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC940>
# - ogdwien:LAMPENTAUSCHOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0AC9A0>
# - ogdwien:LANDESGRENZEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACA00>
# - ogdwien:LANDSCHUTZGEBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACA60>
# - ogdwien:LUFTGUETENETZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACAC0>
# - ogdwien:LAERMSCHUTZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACB20>
# - ogdwien:LAERMSCHUTZWANDOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACB80>
# - ogdwien:MZKBLATT1000OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACBE0>
# - ogdwien:MZKBLATT5000OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACC40>
# - ogdwien:MARATHONOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACCA0>
# - ogdwien:MAUEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACD00>
# - ogdwien:MISTPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACD60>
# - ogdwien:BURGSCHLOSSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACDC0>
# - ogdwien:MITTELALTMAUEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACE20>
# - ogdwien:MITTELALTSDLGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACE80>
# - ogdwien:MITTELALTBEFESTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACEE0>
# - ogdwien:MONUMENTALBRUOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACF40>
# - ogdwien:MOTORRADABSTELLPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0ACFA0>
# - ogdwien:MULTIMEDIAOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093040>
# - ogdwien:MUSEUMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0930A0>
# - ogdwien:MUSIKSINGSCHULEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093100>
# - ogdwien:NATIONALPARKOGD_B: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093160>
# - ogdwien:NATURA2TOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0931C0>
# - ogdwien:NATURA2TVOGELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093220>
# - ogdwien:NATDENKMALPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093280>
# - ogdwien:NATURSCHUTZGEBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0932E0>
# - ogdwien:NETZWERKNATLINOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093340>
# - ogdwien:NETZWERKIBEZFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0933A0>
# - ogdwien:NETZWERKNATFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093400>
# - ogdwien:NETZWERKIBEZLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093460>
# - ogdwien:NETZWERKNATPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0934C0>
# - ogdwien:COVIDFFP2PFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093520>
# - ogdwien:PVPOTENZIALEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093580>
# - ogdwien:PARKINFOOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0935E0>
# - ogdwien:PARKLETSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093640>
# - ogdwien:PARKENAUTOMATOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0936A0>
# - ogdwien:PARKENVERKAUFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093700>
# - ogdwien:PARTIZIPATIONOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093760>
# - ogdwien:PFARRSPRENGELOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0937C0>
# - ogdwien:POLIZEIOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093820>
# - ogdwien:ERDWSONDOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093880>
# - ogdwien:THERMLEISTKLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0938E0>
# - ogdwien:PROBLEMSTOFFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093940>
# - ogdwien:BAUBLOCKOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0939A0>
# - ogdwien:RADGEGENEINBAHNOG: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093A00>
# - ogdwien:RADNETZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093A60>
# - ogdwien:RADNETZPLANUNGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093AC0>
# - ogdwien:RADSERVICEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093B20>
# - ogdwien:RADWEGEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093B80>
# - ogdwien:RAMSAROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093BE0>
# - ogdwien:REALNUT2016GOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093C40>
# - ogdwien:REALNUT2001OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093CA0>
# - ogdwien:REALNUT2003OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093D00>
# - ogdwien:REALNUT2005OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093D60>
# - ogdwien:REALNUT200708OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093DC0>
# - ogdwien:REALNUT2009OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093E20>
# - ogdwien:REALNUT2012OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093E80>
# - ogdwien:REALNUT2018OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093EE0>
# - ogdwien:REALNUT2020OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093F40>
# - ogdwien:REALNUT2014OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB093FA0>
# - ogdwien:REITWEGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083040>
# - ogdwien:RELIGIONOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0830A0>
# - ogdwien:SISBELAGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083100>
# - ogdwien:SISBORDSTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083160>
# - ogdwien:SCHIFFANLEGESTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0831C0>
# - ogdwien:SCHULEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083220>
# - ogdwien:SCHUTZZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083280>
# - ogdwien:SCHWIMMBADOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0832E0>
# - ogdwien:SEHENSWUERDIGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083340>
# - ogdwien:SICHTBARKEITOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0833A0>
# - ogdwien:SILVESPFADLINOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083400>
# - ogdwien:SILVESPFADPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083460>
# - ogdwien:SIRENEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0834C0>
# - ogdwien:SOLARANLAGLSTGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083520>
# - ogdwien:SOMMERSPRITZEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083580>
# - ogdwien:ENSONSTANLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0835E0>
# - ogdwien:SOZIALMARKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083640>
# - ogdwien:SPIELPLATZPUNKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0836A0>
# - ogdwien:SPORTSTAETTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083700>
# - ogdwien:STADTBEFESTIGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083760>
# - ogdwien:STADTKASSEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0837C0>
# - ogdwien:SPAZIERLINIEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083820>
# - ogdwien:SPAZIERPUNKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083880>
# - ogdwien:STRUKALLEEBAUMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0838E0>
# - ogdwien:STRUKALLEEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083940>
# - ogdwien:STRUKBRUNNENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0839A0>
# - ogdwien:STRUKDOMINANTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083A00>
# - ogdwien:STRUKGESCHSTROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083A60>
# - ogdwien:STRUKGRUENRAUMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083AC0>
# - ogdwien:STRUKMARKSITOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083B20>
# - ogdwien:STRUKBLICKPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083B80>
# - ogdwien:STRUKKOMPLEXOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083BE0>
# - ogdwien:STRUKBAUWERKEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083C40>
# - ogdwien:STRUKPLATZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083CA0>
# - ogdwien:STRUKGESTALTBEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083D00>
# - ogdwien:STRUKRAUMKANTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083D60>
# - ogdwien:STATIONENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083DC0>
# - ogdwien:STEHENDEGEWOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083E20>
# - ogdwien:PLANUNGBIMHALTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083E80>
# - ogdwien:PLANUNGBIMOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083EE0>
# - ogdwien:ASFINAGSTRASSEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083F40>
# - ogdwien:ASFINAGSPEEDOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB083FA0>
# - ogdwien:ASFINAGKNOTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075040>
# - ogdwien:STRASSENGRAPHOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0750A0>
# - ogdwien:STRASSENSPEEDOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075100>
# - ogdwien:STRASSENKNOTENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075160>
# - ogdwien:STRKONSTRUKTPOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0751C0>
# - ogdwien:AMTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075220>
# - ogdwien:BLINDENLEITSYSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075280>
# - ogdwien:TAXIOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0752E0>
# - ogdwien:TEMPOZONEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075340>
# - ogdwien:THEMENRADWEGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0753A0>
# - ogdwien:TOURISTIKLINIEBIGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075400>
# - ogdwien:TOURISTIKLINIEVALOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075460>
# - ogdwien:TOURISTIKLINIEVSLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0754C0>
# - ogdwien:TOURISTIKHTSBIGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075520>
# - ogdwien:TOURISTIKHTSVALOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075580>
# - ogdwien:TOURISTIKHTSVSLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0755E0>
# - ogdwien:TRAUMHOCHZEITOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075640>
# - ogdwien:TRINKBRUNNENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0756A0>
# - ogdwien:UBAHNHALTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075700>
# - ogdwien:PLANUNGUBHALTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075760>
# - ogdwien:PLANUNGUBAHNOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0757C0>
# - ogdwien:UBAHNOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075820>
# - ogdwien:UNIVERSITAETOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075880>
# - ogdwien:VOLKSHOCHSCHULEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0758E0>
# - ogdwien:VORTEILSCLUBOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075940>
# - ogdwien:WCANLAGE2OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0759A0>
# - ogdwien:WCANLAGEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075A00>
# - ogdwien:WLANWIENATOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075A60>
# - ogdwien:WAHLERGEBNISNR191OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075AC0>
# - ogdwien:WAHLLOKALOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075B20>
# - ogdwien:WAHLSPRBP2010OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075B80>
# - ogdwien:WAHLSPREU2009OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075BE0>
# - ogdwien:WAHLSPREU2014OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075C40>
# - ogdwien:WAHLSPRGR2020OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075CA0>
# - ogdwien:WAHLSPRGR2005OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075D00>
# - ogdwien:WAHLSPRGR2010OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075D60>
# - ogdwien:WAHLSPRGR2015OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075DC0>
# - ogdwien:WAHLSPRNR2006OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075E20>
# - ogdwien:WAHLSPRNR2008OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075E80>
# - ogdwien:WAHLSPRNR2013OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075EE0>
# - ogdwien:WAHLSPRVB2013OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075F40>
# - ogdwien:WAHLSPRBP2016OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB075FA0>
# - ogdwien:WAHLSPRBP2022OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063040>
# - ogdwien:WAHLSPRNR2017OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0630A0>
# - ogdwien:WAHLSPRNR2019OGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063100>
# - ogdwien:WALDSPIELPLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063160>
# - ogdwien:WANDERWEGEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0631C0>
# - ogdwien:WANDERWEGLAINZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063220>
# - ogdwien:WANDERWEGLOBAUOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063280>
# - ogdwien:WASSERSCHUTZOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0632E0>
# - ogdwien:WEGWEISEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063340>
# - ogdwien:ADVENTMARKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0633A0>
# - ogdwien:WELTKULTERBEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063400>
# - ogdwien:WERBETRAEGERLINOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063460>
# - ogdwien:WERBETRAEGERPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0634C0>
# - ogdwien:WIENTOURISMUSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063520>
# - ogdwien:AUFZUGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063580>
# - ogdwien:WLANWRLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0635E0>
# - ogdwien:MARKTFLAECHEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063640>
# - ogdwien:MAERKTEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0636A0>
# - ogdwien:WIENERWOHNENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063700>
# - ogdwien:ENWINDPOTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063760>
# - ogdwien:WOHNPFLEGEHAUSOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0637C0>
# - ogdwien:WOHNPARTNEROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063820>
# - ogdwien:WOHNSTRASSEOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063880>
# - ogdwien:ENGEFWPANLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0638E0>
# - ogdwien:ZUGANGSADROGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063940>
# - ogdwien:ZAEHLBEZIRKOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB0639A0>
# - ogdwien:ZAEHLGEBIETOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063A00>
# - ogdwien:BASEMAPVERDOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063A60>
# - ogdwien:MOBPROBLEMSTOFFOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063AC0>
# - ogdwien:PROSAMOBILOEFFZEITOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063B20>
# - ogdwien:BAUSTELLENLINOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063B80>
# - ogdwien:BAUSTELLENPKTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063BE0>
# - ogdwien:OEFFGRUENFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063C40>
# - ogdwien:OEFFGRUENLINGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063CA0>
# - ogdwien:OEFFGRUENPKTGOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063D00>
# - ogdwien:OEFFHALTESTOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063D60>
# - ogdwien:OEFFLINIENOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063DC0>
# - ogdwien:OEKOLENTFLOGD: <owslib.feature.wfs110.ContentMetadata object at 0x000002AACB063E20>

# %%
# Choose a specific layer
layer_name = 'ogdwien:SOLARANLAGLSTGOGD'
layer = wfs[layer_name]
layer.__dict__
# Out:
# {'auth': <Authentication shared=False username=None password=None cert=None verify=True auth_delegate=None>,
#  'headers': None,
#  'id': 'ogdwien:SOLARANLAGLSTGOGD',
#  'title': 'Solarpotential 2022 Leistung',
#  'abstract': None,
#  'keywords': ['features', 'V_OGD_SOLARPOT2022_LEISTG_F'],
#  'boundingBoxWGS84': (16.187039178691105,
#   48.120313294392396,
#   16.577143629025443,
#   48.31874678043532),
#  'crsOptions': [urn:x-ogc:def:crs:EPSG::31256],
#  'verbOptions': [],
#  'outputFormats': [],
#  'metadataUrls': [],
#  'styles': None,
#  'timepositions': None,
#  'defaulttimeposition': None}

# %%
wfs.get_schema(layer_name)
# Out:
# {'properties': {'OBJECTID': 'decimal',
#   'STR': 'string',
#   'ONR': 'string',
#   'ADRESSE': 'string',
#   'BEZ': 'string',
#   'YR': 'decimal',
#   'SCHLECHT': 'decimal',
#   'MITTEL': 'decimal',
#   'GUT': 'decimal',
#   'SEHRGUT': 'decimal',
#   'ANLAGENLEISTUNG': 'decimal'},
#  'required': ['OBJECTID'],
#  'geometry': 'GeometryCollection',
#  'geometry_column': 'SHAPE'}

# %%
# Perform a basic GetFeature request
##from owslib.fes import *
#filter = PropertyIsLike(propertyname='OBJECTID', literal="" , wildCard='*')
#filterxml = etree.tostring(filter.toXML()).decode("utf-8")

# Perform a basic GetFeature request
import json


response = wfs.getfeature(
    typename=layer_name,
    #bbox= (16.187039178691105,
  #48.120313294392396,
 # 16.577143629025443,
  #48.31874678043532),  # Vienna bounding box
    srsname='urn:x-ogc:def:crs:EPSG:31256',
    maxfeatures=10,
    outputFormat="JSON",
    )

# %%
json_features = response.read()
json_features
# Out:
# b'{"type":"FeatureCollection","features":[{"type":"Feature","id":"SOLARANLAGLSTGOGD.35","geometry":{"type":"Polygon","coordinates":[[[-2145.891,338315.798],[-2147.44,338316.34],[-2155.57,338319.22],[-2155.65,338318.98],[-2156.27,338317.12],[-2156.59,338317.24],[-2157.429,338314.813],[-2160.34,338306.39],[-2151.53,338303.31],[-2151.365,338303.828],[-2148.164,338313.846],[-2148.07,338314.14],[-2148.19,338314.19],[-2147.988,338314.746],[-2147.67,338315.62],[-2144.93,338314.62],[-2144.67,338315.37],[-2145.891,338315.798]]]},"geometry_name":"SHAPE","properties":{"OBJECTID":35,"STR":" ","ONR":" ","ADRESSE":" ","BEZ":" ","YR":1122.2840651,"SCHLECHT":1,"MITTEL":19,"GUT":48,"SEHRGUT":21,"ANLAGENLEISTUNG":4}},{"type":"Feature","id":"SOLARANLAGLSTGOGD.36","geometry":{"type":"Polygon","coordinates":[[[-4637.9,340351.01],[-4640.96,340351.03],[-4640.94,340353.83],[-4653.3,340353.93],[-4653.41,340340.18],[-4642.57,340340.092],[-4641.319,340340.082],[-4641.06,340340.08],[-4641.01,340344.82],[-4638.88,340344.813],[-4638.63,340344.812],[-4637.95,340344.81],[-4637.9,340351.01]]]},"geometry_name":"SHAPE","properties":{"OBJECTID":36,"STR":"Minorgasse","ONR":"74","ADRESSE":"14., Minorgasse 74","BEZ":"1140","YR":1041.6187741,"SCHLECHT":15,"MITTEL":38,"GUT":38,"SEHRGUT":0,"ANLAGENLEISTUNG":2}},{"type":"Feature","id":"SOLARANLAGLSTGOGD.37","geometry":{"type":"Polygon","coordinates":[[[1949.9,339933.85],[1946.71,339938.5],[1945.35,339937.57],[1941.389,339943.341],[1938.54,339947.49],[1937.72,339946.93],[1932.036,339943.341],[1928.258,339940.955],[1928.437,339940.666],[1928.703,339940.845],[1930.19,339938.638],[1929.971,339938.479],[1935.453,339930.485],[1936.426,339929.061],[1937.163,339927.982],[1939.497,339924.566],[1941.151,339922.132],[1942.661,339919.911],[1942.848,339919.
]]},
#    'geometry_name': 'SHAPE',
#    'properties': {'OBJECTID': 41,
#     'STR': 'Anton-Ochsenhofer-Gasse',
#     'ONR': '3A',
#     'ADRESSE': '23., Anton-Ochsenhofer-Gasse 3A',
#     'BEZ': '1230',
#     'YR': 1124.56499899,
#     'SCHLECHT': 122,
#     'MITTEL': 145,
#     'GUT': 1991,
#     'SEHRGUT': 33,
#     'ANLAGENLEISTUNG': 93}},
#   {'type': 'Feature',
#    'id': 'SOLARANLAGLSTGOGD.42',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-5230.371, 335027.94],
#       [-5238.501, 335029.217],
#       [-5240.054, 335019.344],
#       [-5231.924, 335018.067],
#       [-5230.371, 335027.94]]]},
#    'geometry_name': 'SHAPE',
#    'properties': {'OBJECTID': 42,
#     'STR': 'Blumentalgasse',
#     'ONR': '4',
#     'ADRESSE': '23., Blumentalgasse 4',
#     'BEZ': '1230',
#     'YR': 1101.1900384,
#     'SCHLECHT': 0,
#     'MITTEL': 7,
#     'GUT': 29,
#     'SEHRGUT': 18,
#     'ANLAGENLEISTUNG': 3}},
#   {'type': 'Feature',
#    'id': 'SOLARANLAGLSTGOGD.43',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-6838.905, 340999.037],
#       [-6838.39, 341000],
#       [-6835.76, 341004.92],
#       [-6833.37, 341003.64],
#       [-6831.7, 341006.78],
#       [-6834.09, 341008.06],
#       [-6834.58, 341008.32],
#       [-6833.57, 341010.19],
#       [-6838.535, 341012.851],
#       [-6839.546, 341010.97],
#       [-6842.74, 341012.69],
#       [-6849.52, 341000],
#       [-6853.4, 340992.75],
#       [-6851.228, 340991.589],
#       [-6851.749, 340990.615],
#       [-6848.125, 340988.678],
#       [-6847.605, 340989.652],
#       [-6844.74, 340988.12],
#       [-6841.315, 340994.527],
#       [-6838.905, 340999.037]]]},
#    'geometry_name': 'SHAPE',
#    'properties': {'OBJECTID': 43,
#     'STR': 'Pfarrwiesenstraße',
#     'ONR': '21',
#     'ADRESSE': '14., Pfarrwiesenstraße 21',
#     'BEZ': '1140',
#     'YR': 1107.845318,
#     'SCHLECHT': 11,
#     'MITTEL': 12,
#     'GUT': 133,
#     'SEHRGUT': 13,
#     'ANLAGENLEISTUNG': 9}},
#   {'type': 'Feature',
#    'id': 'SOLARANLAGLSTGOGD.44',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-6869.11, 341117.813],
#       [-6870.51, 341117.85],
#       [-6870.682, 341111.454],
#       [-6870.157, 341111.432],
#       [-6867.921, 341111.337],
#       [-6867.326, 341111.312],
#       [-6867.15, 341117.76],
#       [-6868.21, 341117.788],
#       [-6869.11, 341117.813]]]},
#    'geometry_name': 'SHAPE',
#    'properties': {'OBJECTID': 44,
#     'STR': ' ',
#     'ONR': ' ',
#     'ADRESSE': ' ',
#     'BEZ': ' ',
#     'YR': 1003.5547497,
#     'SCHLECHT': 1,
#     'MITTEL': 6,
#     'GUT': 5,
#     'SEHRGUT': 0,
#     'ANLAGENLEISTUNG': 0}}],
#  'totalFeatures': 185261,
#  'numberMatched': 185261,
#  'numberReturned': 10,
#  'timeStamp': '2023-12-13T19:34:01.241Z',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:EPSG::31256'}}}

# %%
features = feature_collection["features"]
for feature in features:
    print(feature['properties'])
# Out:
# {'OBJECTID': 35, 'STR': ' ', 'ONR': ' ', 'ADRESSE': ' ', 'BEZ': ' ', 'YR': 1122.2840651, 'SCHLECHT': 1, 'MITTEL': 19, 'GUT': 48, 'SEHRGUT': 21, 'ANLAGENLEISTUNG': 4}
# {'OBJECTID': 36, 'STR': 'Minorgasse', 'ONR': '74', 'ADRESSE': '14., Minorgasse 74', 'BEZ': '1140', 'YR': 1041.6187741, 'SCHLECHT': 15, 'MITTEL': 38, 'GUT': 38, 'SEHRGUT': 0, 'ANLAGENLEISTUNG': 2}
# {'OBJECTID': 37, 'STR': 'Stiegengasse', 'ONR': '6', 'ADRESSE': '6., Stiegengasse 6', 'BEZ': '1060', 'YR': 1089.81610074, 'SCHLECHT': 25, 'MITTEL': 112, 'GUT': 208, 'SEHRGUT': 36, 'ANLAGENLEISTUNG': 15}
# {'OBJECTID': 38, 'STR': 'Tewelegasse', 'ONR': '10', 'ADRESSE': '13., Tewelegasse 10', 'BEZ': '1130', 'YR': 1177.5480808, 'SCHLECHT': 0, 'MITTEL': 1, 'GUT': 4, 'SEHRGUT': 16, 'ANLAGENLEISTUNG': 1}
# {'OBJECTID': 39, 'STR': 'Gablenzgasse', 'ONR': '26', 'ADRESSE': '16., Gablenzgasse 26', 'BEZ': '1160', 'YR': 1164.3135829, 'SCHLECHT': 4, 'MITTEL': 49, 'GUT': 140, 'SEHRGUT': 157, 'ANLAGENLEISTUNG': 19}
# {'OBJECTID': 40, 'STR': 'Gallitzinstraße', 'ONR': '89', 'ADRESSE': '16., Gallitzinstraße 89', 'BEZ': '1160', 'YR': 1134.1902028, 'SCHLECHT': 11, 'MITTEL': 13, 'GUT': 23, 'SEHRGUT': 1, 'ANLAGENLEISTUNG': 2}
# {'OBJECTID': 41, 'STR': 'Anton-Ochsenhofer-Gasse', 'ONR': '3A', 'ADRESSE': '23., Anton-Ochsenhofer-Gasse 3A', 'BEZ': '1230', 'YR': 1124.56499899, 'SCHLECHT': 122, 'MITTEL': 145, 'GUT': 1991, 'SEHRGUT': 33, 'ANLAGENLEISTUNG': 93}
# {'OBJECTID': 42, 'STR': 'Blumentalgasse', 'ONR': '4', 'ADRESSE': '23., Blumentalgasse 4', 'BEZ': '1230', 'YR': 1101.1900384, 'SCHLECHT': 0, 'MITTEL': 7, 'GUT': 29, 'SEHRGUT': 18, 'ANLAGENLEISTUNG': 3}
# {'OBJECTID': 43, 'STR': 'Pfarrwiesenstraße', 'ONR': '21', 'ADRESSE': '14., Pfarrwiesenstraße 21', 'BEZ': '1140', 'YR': 1107.845318, 'SCHLECHT': 11, 'MITTEL': 12, 'GUT': 133, 'SEHRGUT': 13, 'ANLAGENLEISTUNG': 9}
# {'OBJECTID': 44, 'STR': ' ', 'ONR': ' ', 'ADRESSE': ' ', 'BEZ': ' ', 'YR': 1003.5547497, 'SCHLECHT': 1, 'MITTEL': 6, 'GUT': 5, 'SEHRGUT': 0, 'ANLAGENLEISTUNG': 0}

# %%
formatted_features = []
addressbuch = dict()
addressbuch2 = list()
for feature in features:
    geometry_type = feature['geometry']['type']
    coordinates = feature['geometry']['coordinates']
    properties = feature['properties']
    adresse = feature['properties']['ADRESSE']
    #bezi = feature ['properties'] ["BEZ"] #WAR NUR FÜR TESTZWECKE
    leistung = feature ['properties'] ['YR']
    anlagenleistung= feature ['properties'] ['ANLAGENLEISTUNG']
    #if bezi!=' ': #WAR NUR FÜR TESTZWECKE
        #print(f"Properties: {properties}") 
        #print(f"Bezirk: {bezi}")
        #print(f"Adresse: {adresse}")
        #print(f"PV-Leistung: {leistung}")
        #print(f"Anlagenleistung: {anlagenleistung}")
        #print(f"Polygon: Coordinates: {coordinates}")
    if geometry_type == 'Polygon':
        # Process polygon coordinates as needed
        print(f"Adresse: {adresse}")
        print(f"Polygon: Coordinates: {coordinates}")

    # Process other information as needed
    
    #properties = feature['properties']
    #formatted_features={"Anlagenleistung":anlagenleistung,"PV-Leistung":leistung}
    addressbuch[adresse] = feature["properties"]
    addressbuch2.append(feature["properties"] ["ADRESSE"]) #adressbuch2 is a list which is used in order to check the input of the user
# Out:
# Adresse:
# Polygon: Coordinates: [[[-2145.891, 338315.798], [-2147.44, 338316.34], [-2155.57, 338319.22], [-2155.65, 338318.98], [-2156.27, 338317.12], [-2156.59, 338317.24], [-2157.429, 338314.813], [-2160.34, 338306.39], [-2151.53, 338303.31], [-2151.365, 338303.828], [-2148.164, 338313.846], [-2148.07, 338314.14], [-2148.19, 338314.19], [-2147.988, 338314.746], [-2147.67, 338315.62], [-2144.93, 338314.62], [-2144.67, 338315.37], [-2145.891, 338315.798]]]
# Adresse: 14., Minorgasse 74
# Polygon: Coordinates: [[[-4637.9, 340351.01], [-4640.96, 340351.03], [-4640.94, 340353.83], [-4653.3, 340353.93], [-4653.41, 340340.18], [-4642.57, 340340.092], [-4641.319, 340340.082], [-4641.06, 340340.08], [-4641.01, 340344.82], [-4638.88, 340344.813], [-4638.63, 340344.812], [-4637.95, 340344.81], [-4637.9, 340351.01]]]
# Adresse: 6., Stiegengasse 6
# Polygon: Coordinates: [[[1949.9, 339933.85], [1946.71, 339938.5], [1945.35, 339937.57], [1941.389, 339943.341], [1938.54, 339947.49], [1937.72, 339946.93], [1932.036, 339943.341], [1928.258, 339940.955], [1928.437, 339940.666], [1928.703, 339940.845], [1930.19, 339938.638], [1929.971, 339938.479], [1935.453, 339930.485], [1936.426, 339929.061], [1937.163, 339927.982], [1939.497, 339924.566], [1941.151, 339922.132], [1942.661, 339919.911], [1942.848, 339919.636], [1942.905, 339919.669], [1944.167, 339920.523], [1952.96, 339926.47], [1948.54, 339932.92], [1949.9, 339933.85]]]
# Adresse: 13., Tewelegasse 10
# Polygon: Coordinates: [[[-4057.3, 336081.55], [-4058.35, 336080.36], [-4061.81, 336083.41], [-4063.839, 336081.123], [-4060.38, 336078.063], [-4062.63, 336075.52], [-4060.86, 336073.87], [-4061.74, 336072.91], [-4058.72, 336070.12], [-4057.84, 336071.08], [-4055.8, 336069.18], [-4050.361, 336075.351], [-4057.3, 336081.55]]]
# Adresse: 16., Gablenzgasse 26
# Polygon: Coordinates: [[[22.15, 340681.2], [20.462, 340681.588], [11.071, 340683.746], [9.55, 340677.1], [8.63, 340677.31], [8.07, 340674.85], [8.99, 340674.64], [8.45, 340672.28], [7.17, 340671.42], [3.762, 340672.194], [4.164, 340674.241], [2.249, 340674.617], [1.858, 340672.625], [0, 340673.05], [-4.64, 340674.141], [-4.89, 340674.2], [-5.107, 340673.221], [-5.26, 340672.53], [-7.
    if 'STR'  in inner_dict:
        del inner_dict['STR']

# %%
# get address from user 
user_address = input("Bitte gib deine Adresse ein (Bezirk,Straße Nr):")

# %%
# check if user_adress is in addressbuch with addressbuch2 which is a list
if user_address in addressbuch2:
    print(addressbuch[user_address])
else:   #if user makes typo he should try again
    print("Please try again")
# Out:
# Please try again

# %%
# Inspect unique values of the property
unique_values = set(feature['properties'].get("ANLAGENLEISTUNG") for feature in features)
print("Unique values of ANLAGENLEISTUNG:", unique_values)
# Out:
# Unique values of ANLAGENLEISTUNG: {0, 1, 2, 3, 4, 9, 15, 19, 93}

# %%
# Convert ANLAGENLEISTUNG to a color scale
min_value = min(unique_values)
max_value = max(unique_values)

def map_to_color(value):
    normalized_value = (value - min_value) / (max_value - min_value)
    # Map the normalized value to a color scale, adjust as needed
    color_value = int(normalized_value * 255)
    return [255 - color_value, color_value, 0, 150]

# Update the get_fill_color parameter
get_fill_color="map_to_color(properties.ANLAGENLEISTUNG)"

# %%
import pydeck as pdk


# Extract polygons and properties
polygons = []
for feature in features:
    geometry_type = feature['geometry']['type']
    coordinates = feature['geometry']['coordinates']
    properties = feature['properties']
    if geometry_type == 'Polygon':
             polygon = {
                "type": "Polygon",
                "coordinates": coordinates,
                "properties": properties  # Replace with the actual property name
                }
    polygons.append(polygon) 
polygons.remove(polygons[0]) #Was used in order to delete the unnecesseary elements with no address
polygons.remove(polygons[-1]) #Was used in order to delete the unnecesseary elements with no address
polygons[6]["properties"]["ANLAGENLEISTUNG"]
# Out:
# 3

# %%
for p in polygons:
    print(p["properties"]["ADRESSE"],p["properties"]["ANLAGENLEISTUNG"])

p = polygons[0]
testadresse = p["properties"]["ADRESSE"]
# Out:
# 14., Minorgasse 74 2
# 6., Stiegengasse 6 15
# 13., Tewelegasse 10 1
# 16., Gablenzgasse 26 19
# 16., Gallitzinstraße 89 2
# 23., Anton-Ochsenhofer-Gasse 3A 93
# 23., Blumentalgasse 4 3
# 14., Pfarrwiesenstraße 21 9

# %%
coords = p["coordinates"][0][0]

# %%
# Create a Pydeck layer for the polygons
layer = pdk.Layer(
    "GeoJsonLayer",
    data=feature_collection,
    get_polygon="coordinates",
    get_fill_color=[255,255,255],#get_fill_color,  # Adjust color based on ANLAGENLEISTUNG
    get_line_color=[200, 255, 200],
    get_line_width=10,
    get_elevation='properties.ANLAGENLEISTUNG'
)
# Set the initial view state (adjust as needed)
view_state = pdk.ViewState(
    latitude=coordinates[0],
    longitude=coordinates[1],
    zoom=18,
)

# Create a Pydeck deck
deck = pdk.Deck( layers=[layer],initial_view_state=view_state)
deck
# Out:
# {
#   "initialViewState": {
#     "latitude": 48.2024752,
#     "longitude": 16.2784412,
#     "zoom": 18
#   },
#   "layers": [
#     {
#       "@@type": "GeoJsonLayer",
#       "data": {
#         "crs": {
#           "properties": {
#             "name": "urn:ogc:def:crs:EPSG::31256"
#           },
#           "type": "name"
#         },
#         "features": [
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -2145.891,
#                     338315.798
#                   ],
#                   [
#                     -2147.44,
#                     338316.34
#                   ],
#                   [
#                     -2155.57,
#                     338319.22
#                   ],
#                   [
#                     -2155.65,
#                     338318.98
#                   ],
#                   [
#                     -2156.27,
#                     338317.12
#                   ],
#                   [
#                     -2156.59,
#                     338317.24
#                   ],
#                   [
#                     -2157.429,
#                     338314.813
#                   ],
#                   [
#                     -2160.34,
#                     338306.39
#                   ],
#                   [
#                     -2151.53,
#                     338303.31
#                   ],
#                   [
#                     -2151.365,
#                     338303.828
#                   ],
#                   [
#                     -2148.164,
#                     338313.846
#                   ],
#                   [
#                     -2148.07,
#                     338314.14
#                   ],
#                   [
#                     -2148.19,
#                     338314.19
#                   ],
#                   [
#                     -2147.988,
#                     338314.746
#                   ],
#                   [
#                     -2147.67,
#                     338315.62
#                   ],
#                   [
#                     -2144.93,
#                     338314.62
#                   ],
#                   [
#                     -2144.67,
#                     338315.37
#                   ],
#                   [
#                     -2145.891,
#                     338315.798
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.35",
#             "properties": {
#               "ADRESSE": " ",
#               "ANLAGENLEISTUNG": 4,
#               "BEZ": " ",
#               "GUT": 48,
#               "MITTEL": 19,
#               "OBJECTID": 35,
#               "ONR": " ",
#               "SCHLECHT": 1,
#               "SEHRGUT": 21,
#               "STR": " ",
#               "YR": 1122.2840651
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -4637.9,
#                     340351.01
#                   ],
#                   [
#                     -4640.96,
#                     340351.03
#                   ],
#                   [
#                     -4640.94,
#                     340353.83
#                   ],
#                   [
#                     -4653.3,
#                     340353.93
#                   ],
#                   [
#                     -4653.41,
#                     340340.18
#                   ],
#                   [
#                     -4642.57,
#                     340340.092
#                   ],
#                   [
#                     -4641.319,
#                     340340.082
#                   ],
#                   [
#                     -4641.06,
#                     340340.08
#                   ],
#                   [
#                     -4641.01,
#                     340344.82
#                   ],
#                   [
#                     -4638.88,
#                     340344.813
#                   ],
#                   [
#                     -4638.63,
#                     340344.812
#                   ],
#                   [
#                     -4637.95,
#                     340344.81
#                   ],
#                   [
#                     -4637.9,
#                     340351.01
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.36",
#             "properties": {
#               "ADRESSE": "14., Minorgasse 74",
#               "ANLAGENLEISTUNG": 2,
#               "BEZ": "1140",
#               "GUT": 38,
#               "MITTEL": 38,
#               "OBJECTID": 36,
#               "ONR": "74",
#               "SCHLECHT": 15,
#               "SEHRGUT": 0,
#               "YR": 1041.6187741
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     1949.9,
#                     339933.85
#                   ],
#                   [
#                     1946.71,
#                     339938.5
#                   ],
#                   [
#                     1945.35,
#                     339937.57
#                   ],
#                   [
#                     1941.389,
#                     339943.341
#                   ],
#                   [
#                     1938.54,
#                     339947.49
#                   ],
#                   [
#                     1937.72,
#                     339946.93
#                   ],
#                   [
#                     1932.036,
#                     339943.341
#                   ],
#                   [
#                     1928.258,
#                     339940.955
#                   ],
#                   [
#                     1928.437,
#                     339940.666
#                   ],
#                   [
#                     1928.703,
#                     339940.845
#                   ],
#                   [
#                     1930.19,
#                     339938.638
#                   ],
#                   [
#                     1929.971,
#                     339938.479
#                   ],
#                   [
#                     1935.453,
#                     339930.485
#                   ],
#                   [
#                     1936.426,
#                     339929.061
#                   ],
#                   [
#                     1937.163,
#                     339927.982
#                   ],
#                   [
#                     1939.497,
#                     339924.566
#                   ],
#                   [
#                     1941.151,
#                     339922.132
#                   ],
#                   [
#                     1942.661,
#                     339919.911
#                   ],
#                   [
#                     1942.848,
#                     339919.636
#                   ],
#                   [
#                     1942.905,
#                     339919.669
#                   ],
#                   [
#                     1944.167,
#                     339920.523
#                   ],
#                   [
#                     1952.96,
#                     339926.47
#                   ],
#                   [
#                     1948.54,
#                     339932.92
#                   ],
#                   [
#                     1949.9,
#                     339933.85
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.37",
#             "properties": {
#               "ADRESSE": "6., Stiegengasse 6",
#               "ANLAGENLEISTUNG": 15,
#               "BEZ": "1060",
#               "GUT": 208,
#               "MITTEL": 112,
#               "OBJECTID": 37,
#               "ONR": "6",
#               "SCHLECHT": 25,
#               "SEHRGUT": 36,
#               "YR": 1089.81610074
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -4057.3,
#                     336081.55
#                   ],
#                   [
#                     -4058.35,
#                     336080.36
#                   ],
#                   [
#                     -4061.81,
#                     336083.41
#                   ],
#                   [
#                     -4063.839,
#                     336081.123
#                   ],
#                   [
#                     -4060.38,
#                     336078.063
#                   ],
#                   [
#                     -4062.63,
#                     336075.52
#                   ],
#                   [
#                     -4060.86,
#                     336073.87
#                   ],
#                   [
#                     -4061.74,
#                     336072.91
#                   ],
#                   [
#                     -4058.72,
#                     336070.12
#                   ],
#                   [
#                     -4057.84,
#                     336071.08
#                   ],
#                   [
#                     -4055.8,
#                     336069.18
#                   ],
#                   [
#                     -4050.361,
#                     336075.351
#                   ],
#                   [
#                     -4057.3,
#                     336081.55
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.38",
#             "properties": {
#               "ADRESSE": "13., Tewelegasse 10",
#               "ANLAGENLEISTUNG": 1,
#               "BEZ": "1130",
#               "GUT": 4,
#               "MITTEL": 1,
#               "OBJECTID": 38,
#               "ONR": "10",
#               "SCHLECHT": 0,
#               "SEHRGUT": 16,
#               "YR": 1177.5480808
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     22.15,
#                     340681.2
#                   ],
#                   [
#                     20.462,
#                     340681.588
#                   ],
#                   [
#                     11.071,
#                     340683.746
#                   ],
#                   [
#                     9.55,
#                     340677.1
#                   ],
#                   [
#                     8.63,
#                     340677.31
#                   ],
#                   [
#                     8.07,
#                     340674.85
#                   ],
#                   [
#                     8.99,
#                     340674.64
#                   ],
#                   [
#                     8.45,
#                     340672.28
#                   ],
#                   [
#                     7.17,
#                     340671.42
#                   ],
#                   [
#                     3.762,
#                     340672.194
#                   ],
#                   [
#                     4.164,
#                     340674.241
#                   ],
#                   [
#                     2.249,
#                     340674.617
#                   ],
#                   [
#                     1.858,
#                     340672.625
#                   ],
#                   [
#                     0,
#                     340673.05
#                   ],
#                   [
#                     -4.64,
#                     340674.141
#                   ],
#                   [
#                     -4.89,
#                     340674.2
#                   ],
#                   [
#                     -5.107,
#                     340673.221
#                   ],
#                   [
#                     -5.26,
#                     340672.53
#                   ],
#                   [
#                     -7.35,
#                     340663.127
#                   ],
#                   [
#                     -3.491,
#                     340662.223
#                   ],
#                   [
#                     -3.498,
#                     340661.922
#                   ],
#                   [
#                     -2.885,
#                     340661.726
#                   ],
#                   [
#                     -1.025,
#                     340661.296
#                   ],
#                   [
#                     -0.459,
#                     340661.165
#                   ],
#                   [
#                     -0.343,
#                     340661.495
#                   ],
#                   [
#                     0,
#                     340661.415
#                   ],
#                   [
#                     11.172,
#                     340658.797
#                   ],
#                   [
#                     11.181,
#                     340658.734
#                   ],
#                   [
#                     15.32,
#                     340657.77
#                   ],
#                   [
#                     15.33,
#                     340657.91
#                   ],
#                   [
#                     17.07,
#                     340659.08
#                   ],
#                   [
#                     17.18,
#                     340659.07
#                   ],
#                   [
#                     18.12,
#                     340663.24
#                   ],
#                   [
#                     18.05,
#                     340663.25
#                   ],
#                   [
#                     20.462,
#                     340673.808
#                   ],
#                   [
#                     22.15,
#                     340681.2
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.39",
#             "properties": {
#               "ADRESSE": "16., Gablenzgasse 26",
#               "ANLAGENLEISTUNG": 19,
#               "BEZ": "1160",
#               "GUT": 140,
#               "MITTEL": 49,
#               "OBJECTID": 39,
#               "ONR": "26",
#               "SCHLECHT": 4,
#               "SEHRGUT": 157,
#               "YR": 1164.3135829
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -3625.45,
#                     341968.41
#                   ],
#                   [
#                     -3625.93,
#                     341968.68
#                   ],
#                   [
#                     -3624.556,
#                     341971.102
#                   ],
#                   [
#                     -3624.37,
#                     341971.43
#                   ],
#                   [
#                     -3626.417,
#                     341972.587
#                   ],
#                   [
#                     -3627.66,
#                     341973.29
#                   ],
#                   [
#                     -3626.72,
#                     341974.97
#                   ],
#                   [
#                     -3630.16,
#                     341976.91
#                   ],
#                   [
#                     -3629,
#                     341978.94
#                   ],
#                   [
#                     -3631.46,
#                     341980.35
#                   ],
#                   [
#                     -3635.916,
#                     341972.587
#                   ],
#                   [
#                     -3636.769,
#                     341971.102
#                   ],
#                   [
#                     -3637.577,
#                     341969.694
#                   ],
#                   [
#                     -3635.91,
#                     341968.74
#                   ],
#                   [
#                     -3632.02,
#                     341966.54
#                   ],
#                   [
#                     -3632.56,
#                     341965.58
#                   ],
#                   [
#                     -3628.38,
#                     341963.22
#                   ],
#                   [
#                     -3625.45,
#                     341968.41
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.40",
#             "properties": {
#               "ADRESSE": "16., Gallitzinstra\u00dfe 89",
#               "ANLAGENLEISTUNG": 2,
#               "BEZ": "1160",
#               "GUT": 23,
#               "MITTEL": 13,
#               "OBJECTID": 40,
#               "ONR": "89",
#               "SCHLECHT": 11,
#               "SEHRGUT": 1,
#               "YR": 1134.1902028
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     815.294,
#                     334217.212
#                   ],
#                   [
#                     799.355,
#                     334222.054
#                   ],
#                   [
#                     799.419,
#                     334222.255
#                   ],
#                   [
#                     799.212,
#                     334222.298
#                   ],
#                   [
#                     795.7,
#                     334210.74
#                   ],
#                   [
#                     784.89,
#                     334175.181
#                   ],
#                   [
#                     791.43,
#                     334173.21
#                   ],
#                   [
#                     808.78,
#                     334167.98
#                   ],
#                   [
#                     824.284,
#                     334163.306
#                   ],
#                   [
#                     826.86,
#                     334162.53
#                   ],
#                   [
#                     833.265,
#                     334183.602
#                   ],
#                   [
#                     831.286,
#                     334184.204
#                   ],
#                   [
#                     830.676,
#                     334184.389
#                   ],
#                   [
#                     826.562,
#                     334185.639
#                   ],
#                   [
#                     825.411,
#                     334185.989
#                   ],
#                   [
#                     825.114,
#                     334186.079
#                   ],
#                   [
#                     824.837,
#                     334186.164
#                   ],
#                   [
#                     824.552,
#                     334186.25
#                   ],
#                   [
#                     824.255,
#                     334186.341
#                   ],
#                   [
#                     823.966,
#                     334186.428
#                   ],
#                   [
#                     823.675,
#                     334186.517
#                   ],
#                   [
#                     823.388,
#                     334186.604
#                   ],
#                   [
#                     823.104,
#                     334186.69
#                   ],
#                   [
#                     822.823,
#                     334186.776
#                   ],
#                   [
#                     822.53,
#                     334186.865
#                   ],
#                   [
#                     822.243,
#                     334186.952
#                   ],
#                   [
#                     821.962,
#                     334187.037
#                   ],
#                   [
#                     821.68,
#                     334187.123
#                   ],
#                   [
#                     821.377,
#                     334187.215
#                   ],
#                   [
#                     821.072,
#                     334187.308
#                   ],
#                   [
#                     821.439,
#                     334188.513
#                   ],
#                   [
#                     821.962,
#                     334190.234
#                   ],
#                   [
#                     816.086,
#                     334192.02
#                   ],
#                   [
#                     819.57,
#                     334203.48
#                   ],
#                   [
#                     821.771,
#                     334210.725
#                   ],
#                   [
#                     831.294,
#                     334207.826
#                   ],
#                   [
#                     832.554,
#                     334211.965
#                   ],
#                   [
#                     830.269,
#                     334212.66
#                   ],
#                   [
#                     823.028,
#                     334214.864
#                   ],
#                   [
#                     821.065,
#                     334215.46
#                   ],
#                   [
#                     820.121,
#                     334215.747
#                   ],
#                   [
#                     815.294,
#                     334217.212
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.41",
#             "properties": {
#               "ADRESSE": "23., Anton-Ochsenhofer-Gasse 3A",
#               "ANLAGENLEISTUNG": 93,
#               "BEZ": "1230",
#               "GUT": 1991,
#               "MITTEL": 145,
#               "OBJECTID": 41,
#               "ONR": "3A",
#               "SCHLECHT": 122,
#               "SEHRGUT": 33,
#               "YR": 1124.56499899
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -5230.371,
#                     335027.94
#                   ],
#                   [
#                     -5238.501,
#                     335029.217
#                   ],
#                   [
#                     -5240.054,
#                     335019.344
#                   ],
#                   [
#                     -5231.924,
#                     335018.067
#                   ],
#                   [
#                     -5230.371,
#                     335027.94
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.42",
#             "properties": {
#               "ADRESSE": "23., Blumentalgasse 4",
#               "ANLAGENLEISTUNG": 3,
#               "BEZ": "1230",
#               "GUT": 29,
#               "MITTEL": 7,
#               "OBJECTID": 42,
#               "ONR": "4",
#               "SCHLECHT": 0,
#               "SEHRGUT": 18,
#               "YR": 1101.1900384
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -6838.905,
#                     340999.037
#                   ],
#                   [
#                     -6838.39,
#                     341000
#                   ],
#                   [
#                     -6835.76,
#                     341004.92
#                   ],
#                   [
#                     -6833.37,
#                     341003.64
#                   ],
#                   [
#                     -6831.7,
#                     341006.78
#                   ],
#                   [
#                     -6834.09,
#                     341008.06
#                   ],
#                   [
#                     -6834.58,
#                     341008.32
#                   ],
#                   [
#                     -6833.57,
#                     341010.19
#                   ],
#                   [
#                     -6838.535,
#                     341012.851
#                   ],
#                   [
#                     -6839.546,
#                     341010.97
#                   ],
#                   [
#                     -6842.74,
#                     341012.69
#                   ],
#                   [
#                     -6849.52,
#                     341000
#                   ],
#                   [
#                     -6853.4,
#                     340992.75
#                   ],
#                   [
#                     -6851.228,
#                     340991.589
#                   ],
#                   [
#                     -6851.749,
#                     340990.615
#                   ],
#                   [
#                     -6848.125,
#                     340988.678
#                   ],
#                   [
#                     -6847.605,
#                     340989.652
#                   ],
#                   [
#                     -6844.74,
#                     340988.12
#                   ],
#                   [
#                     -6841.315,
#                     340994.527
#                   ],
#                   [
#                     -6838.905,
#                     340999.037
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.43",
#             "properties": {
#               "ADRESSE": "14., Pfarrwiesenstra\u00dfe 21",
#               "ANLAGENLEISTUNG": 9,
#               "BEZ": "1140",
#               "GUT": 133,
#               "MITTEL": 12,
#               "OBJECTID": 43,
#               "ONR": "21",
#               "SCHLECHT": 11,
#               "SEHRGUT": 13,
#               "YR": 1107.845318
#             },
#             "type": "Feature"
#           },
#           {
#             "geometry": {
#               "coordinates": [
#                 [
#                   [
#                     -6869.11,
#                     341117.813
#                   ],
#                   [
#                     -6870.51,
#                     341117.85
#                   ],
#                   [
#                     -6870.682,
#                     341111.454
#                   ],
#                   [
#                     -6870.157,
#                     341111.432
#                   ],
#                   [
#                     -6867.921,
#                     341111.337
#                   ],
#                   [
#                     -6867.326,
#                     341111.312
#                   ],
#                   [
#                     -6867.15,
#                     341117.76
#                   ],
#                   [
#                     -6868.21,
#                     341117.788
#                   ],
#                   [
#                     -6869.11,
#                     341117.813
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "geometry_name": "SHAPE",
#             "id": "SOLARANLAGLSTGOGD.44",
#             "properties": {
#               "ADRESSE": " ",
#               "ANLAGENLEISTUNG": 0,
#               "BEZ": " ",
#               "GUT": 5,
#               "MITTEL": 6,
#               "OBJECTID": 44,
#               "ONR": " ",
#               "SCHLECHT": 1,
#               "SEHRGUT": 0,
#               "YR": 1003.5547497
#             },
#             "type": "Feature"
#           }
#         ],
#         "numberMatched": 185261,
#         "numberReturned": 10,
#         "timeStamp": "2023-12-13T19:34:01.241Z",
#         "totalFeatures": 185261,
#         "type": "FeatureCollection"
#       },
#       "getElevation": "@@=properties.ANLAGENLEISTUNG",
#       "getFillColor": [
#         255,
#         255,
#         255
#       ],
#       "getLineColor": [
#         200,
#         255,
#         200
#       ],
#       "getLineWidth": 10,
#       "getPolygon": "@@=coordinates",
#       "id": "8683e2cf-2828-4819-97bc-d23d991aadfe"
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %%
testadresse = "Wien, " + testadresse
testadresse
# Out:
# 'Wien, Wien, 14., Minorgasse 74'

# %%
from geopy.geocoders import Nominatim

# Replace 'YourAPIKey' with your actual API key if you're using a service that requires one.
geolocator = Nominatim(user_agent="my_geocoder_app")

def get_lat_long_from_address(address):
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# Example usage:
address = testadresse
coordinates = get_lat_long_from_address(address)

if coordinates:
    print(f"Latitude: {coordinates[0]}, Longitude: {coordinates[1]}")
else:
    print("Could not retrieve coordinates for the given address.")
# Out:
# Latitude: 48.2024752, Longitude: 16.2784412

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\manav\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\manav\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting trio~=0.17
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
# Requirement already satisfied: idna in c:\users\manav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\manav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\manav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\manav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: pycparser in c:\users\manav\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\manav\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
# Successfully installed exceptiongroup-1.1.3 h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 sniffio-1.3.0 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.
